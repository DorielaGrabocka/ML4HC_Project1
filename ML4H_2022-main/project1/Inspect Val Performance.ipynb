# %% [markdown]
# # This notebook shows the hyperparameter search history for the experiments performed

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd

# %%
def display_search_history(dataset, exp_type):
    model_save_dir = exp_type + '_hyperparam_search_' + dataset
    path = model_save_dir + "/hyperparam_search_history.csv"
    
    a = pd.read_csv(path, index_col=0)
    display(a.sort_values("mean_test_f1_score", ascending=False)[["param_module__strides", "param_module__residual", "param_module__n_filters", "param_module__kernel_sizes", "param_module__adaptive_average_len", "param_module__fully_connected_features", "param_criterion__weight", "param_lr", "param_iterator_train__batch_size", "mean_test_accuracy", "mean_test_f1_score"]][:20])

# %%
# TO UPDATE THESE TOO
display_search_history("MITBIH", "shallow")
# Out:
#    param_module__strides  param_module__residual param_module__n_filters  \
# 0                 [2, 1]                   False               [64, 128]
# 7                 [2, 1]                    True               [64, 128]
# 5                 [2, 1]                   False               [64, 128]
# 6                 [2, 1]                   False               [64, 128]
# 13                [2, 1]                   False               [64, 128]
# 3                 [2, 1]                   False               [64, 128]
# 11                [2, 2]                   False               [64, 128]
# 12                [2, 1]                   False                [32, 64]
# 9                 [2, 2]                   False               [64, 128]
# 8                 [2, 1]                    True                [16, 32]
# 1                 [2, 1]                    True                [16, 32]
# 14                [2, 1]                   False                [32, 64]
# ...

# %%
display_search_history("MITBIH", "deep")
# Out:
#    param_module__strides  param_module__residual param_module__n_filters  \
# 5        [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 3        [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 14       [2, 1, 1, 1, 1]                   False    [32, 48, 48, 48, 64]
# 7        [2, 1, 1, 1, 1]                    True   [64, 96, 96, 96, 128]
# 12       [2, 1, 1, 1, 1]                   False    [32, 48, 48, 48, 64]
# 9        [2, 2, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 0        [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 10       [2, 1, 1, 1, 1]                    True    [32, 48, 48, 48, 64]
# 11       [2, 2, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 6        [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 13       [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 8        [2, 1, 1, 1, 1]                    True    [16, 24, 24, 24, 32]
# ...

# %%
display_search_history("PTBDB", "shallow")
# Out:
#    param_module__strides  param_module__residual param_module__n_filters  \
# 21                [2, 1]                   False               [64, 128]
# 3                 [2, 1]                    True               [64, 128]
# 7                 [2, 2]                    True               [64, 128]
# 9                 [2, 1]                    True                [16, 32]
# 0                 [2, 2]                   False               [64, 128]
# 20                [2, 1]                   False               [64, 128]
# 19                [2, 1]                   False                [32, 64]
# 5                 [2, 1]                   False               [64, 128]
# 1                 [2, 2]                    True                [32, 64]
# 16                [2, 2]                   False               [64, 128]
# 23                [2, 2]                   False                [32, 64]
# 10                [2, 2]                   False                [32, 64]
# ...

# %%
display_search_history("PTBDB", "deep")
# Out:
#    param_module__strides  param_module__residual param_module__n_filters  \
# 0        [2, 1, 1, 1, 1]                    True    [32, 48, 48, 48, 64]
# 4        [2, 1, 1, 1, 1]                   False    [32, 48, 48, 48, 64]
# 19       [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 23       [2, 2, 1, 1, 1]                    True    [32, 48, 48, 48, 64]
# 13       [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 24       [2, 1, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 18       [2, 2, 1, 1, 1]                   False    [32, 48, 48, 48, 64]
# 10       [2, 2, 1, 1, 1]                    True    [32, 48, 48, 48, 64]
# 3        [2, 2, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 11       [2, 2, 1, 1, 1]                   False   [64, 96, 96, 96, 128]
# 5        [2, 1, 1, 1, 1]                   False    [32, 48, 48, 48, 64]
# 8        [2, 2, 1, 1, 1]                    True   [64, 96, 96, 96, 128]
# ...
